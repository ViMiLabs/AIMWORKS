# %% [markdown]
# # H2KG release notebook starter
# Load the asserted schema and inspect a few mapped terms.

# %%
from rdflib import Graph
g = Graph()
g.parse('https://w3id.org/h2kg/hydrogen-ontology/source', format='turtle')
len(g)
